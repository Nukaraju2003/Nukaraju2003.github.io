# %% [markdown]
# <a href="https://colab.research.google.com/github/Nukaraju2003/Nukaraju2003.github.io/blob/main/NaiveBayes2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![picture](https://drive.google.com/file/d/1qUWsnVSyIWJ20zmDnP4rsVx-UAoQN_ZJ/view?usp=share_link)
#
# ---
#
#
#
# ---
#
# ![96bb925a-153c-4ff5-bb1f-5f85ba048b2c.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Naive Bayes Implemenatation
# we shall understand Python object oreinted implementation of this algorithm.
# Example case: we want to determine gender from name.

# %%
import nltk
nltk.download('names')
from nltk.corpus import names
# Out:
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Package names is already up-to-date!

# %% [markdown]
# ## Feature Design
# Here we would Plan features for gender identification
#
# Possible features
#
# *  ending character
# *  starting character

# %%
def gender_features(word) :
  """
  This function will take a word and return a dictionary of gender features
  {'feature_name''feature_value}
  """
  word= word.strip().lower()
 # return {'last_letter':word[-1],'first_letter':word[0]} 
  return {'last_letter':word[-1]}

# %%
data = [(gender_features(name), 'female') for name in names.words("female.txt")] + \
 [(gender_features(name), 'male') for name in names.words("male.txt")]

# %%
import random
random.shuffle(data)

# %%
n= len(data)
import math
t_n = math.ceil(0.9*n)
train_data, test_data = data[:t_n], data[t_n:]

# %%
 print(len(train_data), train_data[:10])
# Out:
# 7150 [({'last_letter': 'a'}, 'female'), ({'last_letter': 'o'}, 'male'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'i'}, 'female'), ({'last_letter': 'w'}, 'male'), ({'last_letter': 'n'}, 'male'), ({'last_letter': 'm'}, 'male'), ({'last_letter': 'a'}, 'female'), ({'last_letter': 'e'}, 'female'), ({'last_letter': 'a'}, 'female')]

# %%
class NaiveBayesClassifier:
  """
  Implements a Naive Bayes Classifier
  """

  def __init__(self, training_dataset):
    """
    trains a naive bayes classifier on the. training dataset
    """
    pass

  def _train(self, training_dataset):
    pass
      
  def classify(self, featureset):
    """
    Gives  the argmax or the class predicted or most probable forthe given feature set
    """

# %%
1:54
